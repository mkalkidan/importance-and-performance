# %% [markdown]
# Desktop/TEAM - Dataset/data/dataset_names.txt
# Load the dataset

# %%
import os 
import scipy.io 

# Define the base directory 
base_dir = os.path.join ("Desktop", "TEAM - Dataset", "data")
