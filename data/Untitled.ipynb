# %%
import pickle
import numpy as np
import pandas as pd

# Load everything back into memory instantly
with open("./all_datasets.pkl", "rb") as f:
    all_datasets = pickle.load(f)

print(f"🚀 Success! Loaded {len(all_datasets)} datasets instantly from your pickle file.")
# Out:
# 🚀 Success! Loaded 62 datasets instantly from your pickle file.
